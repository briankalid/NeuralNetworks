# %%
import pandas as pd
import fastai.collab as fc
import fastai.tabular.all as ft

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !ls storage/anime/
# Out:
# animes.csv  profiles.csv  reviews.csv

# %%
animes = pd.read_csv('storage/anime/animes.csv')
animes = animes.drop_duplicates() #animes tiene filas duplicadas
animes
# Out:
#          uid                                                          title  \
# 0      28891                                        Haikyuu!! Second Season
# 1      23273                                        Shigatsu wa Kimi no Uso
# 2      34599                                                  Made in Abyss
# 3       5114                               Fullmetal Alchemist: Brotherhood
# 4      31758                               Kizumonogatari III: Reiketsu-hen
# ...      ...                                                            ...
# 19002  10075                                                    Naruto x UT
# 19003  35828                                               Miira no Kaikata
# 19004  10378                                         Shinryaku!? Ika Musume
# 19005  33082                                  Kingsglaive: Final Fantasy XV
# 19006  16934  Chuunibyou demo Koi ga Shitai!: Kirameki no... Slapstick Noel
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       synopsis  \
# 0      Following their participation at the Inter-High, the Karasuno High School volleyball team attempts to refocus their efforts, aiming to conquer the Spring tournament instead.  \r\n \r\nWhen they receive an invitation from long-standing rival Nekoma High, Karasuno agrees to take part in a large training camp alongside many notable volleyball teams in Tokyo and even some national level players. By playing with some of the toughest teams in Japan, they hope not only to sharpen their skills, but also come up with new attacks that would strengthen them. Moreover, Hinata and Kageyama attempt to d...
# 1      Music accompanies the path of the human metronome, the prodigious pianist Kousei Arima. But after the passing of his mother, Saki Arima, Kousei falls into a downward spiral, rendering him unable to hear the sound of his own piano. \r\n  \r\nTwo years later, Kousei still avoids the piano, leaving behind his admirers and rivals, and lives a colorless life alongside his friends Tsubaki Sawabe and Ryouta Watari. However, everything changes when he meets a beautiful violinist, Kaori Miyazono, who stirs up his world and sets him on a journey to face music again. \r\n \r\nBased on the manga serie...
# 2      The Abyss—a gaping chasm stretching down into the depths of the earth, filled with mysterious creatures and relics from a time long past. How did it come to be? What lies at the bottom? Countless brave individuals, known as Divers, have sought to solve these mysteries of the Abyss, fearlessly descending into its darkest realms. The best and bravest of the Divers, the White Whistles, are hailed as legends by those who remain on the surface. \r\n \r\nRiko, daughter of the missing White Whistle Lyza the Annihilator, aspires to become like her mother and explore the furthest reaches of the Aby...
# 3      "In order for something to be obtained, something of equal value must be lost." \r\n \r\nAlchemy is bound by this Law of Equivalent Exchange—something the young brothers Edward and Alphonse Elric only realize after attempting human transmutation: the one forbidden act of alchemy. They pay a terrible price for their transgression—Edward loses his left leg, Alphonse his physical body. It is only by the desperate sacrifice of Edward's right arm that he is able to affix Alphonse's soul to a suit of armor. Devastated and alone, it is the hope that they would both eventually return to their orig...
# 4      After helping revive the legendary vampire Kiss-shot Acerola-orion Heart-under-blade, Koyomi Araragi has become a vampire himself and her servant. Kiss-shot is certain she can turn him back into a human, but only once regaining her full power.  \r\n \r\nAraragi has hunted down the three vampire hunters that defeated Kiss-shot and retrieved her limbs to return her to full strength. However, now that Araragi has almost accomplished what he’s been fighting for this whole time, he has to consider if this is what he really wants. Once he revives this powerful immortal vampire, there is no telli...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 19002                                                                                                                                                                                                                                                         All-new animation offered throughout UNIQLO clothing stores in Japan on January 1, 2011. The DVD contains an exclusive version of Mayonaka Orchestra, by the Japanese rock band Aqua Timez. A limited number of the DVDs was offered as presents to people who bought UNIQLO's Naruto graphic T-shirts online or in their stores. \r\n \r\n(Source: ANN, edited)
# 19003  High school student Sora Kashiwagi is accustomed to receiving bizarre presents from his father, who is on an expedition around the world. Unfortunately, these gifts have been nothing but nightmares. As a result, when his father sends him a huge package from Egypt, Sora prepares himself for the worst, only to be greeted by Mii-kun—a cute, pint-sized mummy! While initially wary, Sora soon learns that Mii-kun is harmless, a delicate creature yearning for attention. \r\n \r\nThroughout their amusing day-to-day lives, the unlikely pair meet other people with unique pets, while also strengthenin...
# 19004  After regaining her squid-like abilities, Ika Musume plans to resume her self-appointed mission to destroy all of humanity. However, her carefree job as a waitress in the Lemon beach house meant she cannot help but laze around during her spare time! On top of that, she is saddled with many problems, such as being pursued by a group of alien-obsessed individuals and catching the interest of a crazy girl.  \r\n \r\nPicking up after the conclusion of the first season,  Shinryaku!? Ika Musume  follows the hilarious life of Ika Musume as she plots her next invasion of the surface world. \r\n \r...
# 19005  For years, the Niflheim Empire and the kingdom of Lucis have been at war. The empire, having dominated most of the world of Eos, covets the power of the last known Crystal, which is held in Lucis' capital city, Insomnia. \r\n \r\nIn order to protect his people from these advancing forces, King Regis Lucis Caelum CXIII used the power of the Crystal to surround Insomnia with a magical wall. Along with this barrier, Regis assembled an elite military task force known as the Kingsglaive. By drawing their power from the king, the Kingsglaive protect Lucis' borders from the onslaught of the empir...
# 19006  Although Yuuta Togashi and Rikka Takanashi have just started dating, they do not know how to progress their young relationship. Due to both of them being shy, neither of them are capable of making the first move. Rikka decides to ask her class representative Shinka Nibutani for some love advice, and she advises Rikka get closer to Yuuta during the Christmas season. Following the suggestion of Yuuta's friend, Makoto Isshiki, they hold a Christmas party at Sanae Dekomori’s place. \r\n \r\nDuring the party, Yuuta notices Rikka has gone missing and searches for her. When he finds Rikka, he not...
#
#                                                                                        genre  \
# 0                                         ['Comedy', 'Sports', 'Drama', 'School', 'Shounen']
# 1                                         ['Drama', 'Music', 'Romance', 'School', 'Shounen']
# 2                                     ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'Fantasy']
# 3      ['Action', 'Military', 'Adventure', 'Comedy', 'Drama', 'Magic', 'Fantasy', 'Shounen']
# 4                                           ['Action', 'Mystery', 'Supernatural', 'Vampire']
# ...                                                                                      ...
# 19002                         ['Action', 'Comedy', 'Super Power', 'Martial Arts', 'Shounen']
# 19003                                            ['Slice of Life', 'Comedy', 'Supernatural']
# 19004                                                 ['Slice of Life', 'Comedy', 'Shounen']
# 19005                                                                             ['Action']
# 19006                              ['Comedy', 'Drama', 'Romance', 'School', 'Slice of Life']
#
#                               aired  episodes  members  popularity  ranked  \
# 0       Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0
# 1      Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0
# 2       Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0
# 3        Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0
# 4                       Jan 6, 2017       1.0   214621         502    22.0
# ...                             ...       ...      ...         ...     ...
# 19002                   Jan 1, 2011       1.0    34155        2382  1728.0
# 19003  Jan 12, 2018 to Mar 30, 2018      12.0    61459        1648  1727.0
# 19004  Sep 27, 2011 to Dec 25, 2011      12.0    67422        1547  1548.0
# 19005                   Jul 9, 2016       1.0    41077        2154  1544.0
# 19006                  Jun 19, 2013       1.0   128400         883  1533.0
#
#        score                                                  img_url  \
# 0       8.82     https://cdn.myanimelist.net/images/anime/9/76662.jpg
# 1       8.83     https://cdn.myanimelist.net/images/anime/3/67177.jpg
# 2       8.83     https://cdn.myanimelist.net/images/anime/6/86733.jpg
# 3       9.23  https://cdn.myanimelist.net/images/anime/1223/96541.jpg
# 4       8.83     https://cdn.myanimelist.net/images/anime/3/81576.jpg
# ...      ...                                                      ...
# 19002   7.50     https://cdn.myanimelist.net/images/anime/3/30485.jpg
# 19003   7.50  https://cdn.myanimelist.net/images/anime/1486/93811.jpg
# 19004   7.56     https://cdn.myanimelist.net/images/anime/6/30120.jpg
# 19005   7.56    https://cdn.myanimelist.net/images/anime/12/79392.jpg
# 19006   7.56     https://cdn.myanimelist.net/images/anime/7/45512.jpg
#
#                                                                                                 link
# 0                                          https://myanimelist.net/anime/28891/Haikyuu_Second_Season
# 1                                        https://myanimelist.net/anime/23273/Shigatsu_wa_Kimi_no_Uso
# 2                                                  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3                                https://myanimelist.net/anime/5114/Fullmetal_Alchemist__Brotherhood
# 4                               https://myanimelist.net/anime/31758/Kizumonogatari_III__Reiketsu-hen
# ...                                                                                              ...
# 19002                                                https://myanimelist.net/anime/10075/Naruto_x_UT
# 19003                                           https://myanimelist.net/anime/35828/Miira_no_Kaikata
# 19004                                       https://myanimelist.net/anime/10378/Shinryaku_Ika_Musume
# 19005                              https://myanimelist.net/anime/33082/Kingsglaive__Final_Fantasy_XV
# 19006  https://myanimelist.net/anime/16934/Chuunibyou_demo_Koi_ga_Shitai__Kirameki_no_Slapstick_Noel
#
# [16368 rows x 12 columns]

# %%
# animes[animes['uid']==29111]

# %%
profiles = pd.read_csv('storage/anime/profiles.csv')
profiles = profiles.drop_duplicates() #profiles tiene filas duplicadas

profiles
# Out:
#                profile  gender      birthday  \
# 0       DesolatePsyche    Male   Oct 2, 1994
# 1            baekbeans  Female  Nov 10, 2000
# 2                 skrn     NaN           NaN
# 3         edgewalker00    Male         Sep 5
# 4      aManOfCulture99    Male  Oct 30, 1999
# ...                ...     ...           ...
# 77656       daniel1302     NaN           NaN
# 77657       bridgesams    Male   Jan 1, 2001
# 77659    Officer_Anime     NaN           NaN
# 77660             Yuez     NaN           NaN
# 77662  srry4apologizng     NaN           NaN
#
#                                                                                                                                                              favorites_anime  \
# 0      ['33352', '25013', '5530', '33674', '1482', '269', '18245', '2904', '27899', '17074', '12291', '226', '28851', '8525', '6594', '4981', '1698', '457', '235', '34618']
# 1                                                                                        ['11061', '31964', '853', '20583', '918', '9253', '34599', '3588', '13601', '6956']
# 2                                                                                                 ['918', '2904', '11741', '17074', '23273', '32281', '9989', '1943', '512']
# 3                                                                                                                                   ['5680', '849', '2904', '3588', '37349']
# 4                                                                                           ['4181', '7791', '9617', '5680', '2167', '4382', '849', '235', '35180', '31646']
# ...                                                                                                                                                                      ...
# 77656                                                                                                                                                                     []
# 77657                                                                                                            ['37510', '35180', '30', '31043', '5081', '37450', '11843']
# 77659                                                                                                                                                                     []
# 77660                                                                                                                                                                     []
# 77662                                                                                                                                                                     []
#
#                                                   link
# 0       https://myanimelist.net/profile/DesolatePsyche
# 1            https://myanimelist.net/profile/baekbeans
# 2                 https://myanimelist.net/profile/skrn
# 3         https://myanimelist.net/profile/edgewalker00
# 4      https://myanimelist.net/profile/aManOfCulture99
# ...                                                ...
# 77656       https://myanimelist.net/profile/daniel1302
# 77657       https://myanimelist.net/profile/bridgesams
# 77659    https://myanimelist.net/profile/Officer_Anime
# 77660             https://myanimelist.net/profile/Yuez
# 77662  https://myanimelist.net/profile/srry4apologizng
#
# [47902 rows x 5 columns]

# %%
ratings = pd.read_csv('storage/anime/reviews.csv')
ratings.drop(['text','scores','link'],axis=1,inplace=True)
ratings=ratings.drop_duplicates()
ratings
# Out:
#            uid          profile  anime_uid  score
# 0       255938   DesolatePsyche      34096      8
# 1       259117        baekbeans      34599     10
# 2       253664             skrn      28891      7
# 3         8254     edgewalker00       2904      9
# 4       291149  aManOfCulture99       4181     10
# ...        ...              ...        ...    ...
# 182629  146535        iHitokage       2593     10
# 182631   13126           Onegai       2593      7
# 182633  127899         Murasa22       2593     10
# 182636  286852  srry4apologizng       2593      9
# 182637  193145        bellellis       2593     10
#
# [130519 rows x 4 columns]

# %% [markdown]
# # Join

# %%
joined=ratings.join(profiles[['birthday','gender','profile']].set_index('profile'),on='profile')

joined
# Out:
#            uid          profile  anime_uid  score      birthday  gender
# 0       255938   DesolatePsyche      34096      8   Oct 2, 1994    Male
# 1       259117        baekbeans      34599     10  Nov 10, 2000  Female
# 2       253664             skrn      28891      7           NaN     NaN
# 3         8254     edgewalker00       2904      9         Sep 5    Male
# 4       291149  aManOfCulture99       4181     10  Oct 30, 1999    Male
# ...        ...              ...        ...    ...           ...     ...
# 182629  146535        iHitokage       2593     10           NaN    Male
# 182631   13126           Onegai       2593      7           NaN    Male
# 182633  127899         Murasa22       2593     10  Feb 16, 1993    Male
# 182636  286852  srry4apologizng       2593      9           NaN     NaN
# 182637  193145        bellellis       2593     10           NaN     NaN
#
# [130718 rows x 6 columns]

# %%
joined.rename(columns={'score':'score_user'},inplace=True) #cambio de nombre la columna para no generar conflictos
joined.columns
# Out:
# Index(['uid', 'profile', 'anime_uid', 'score_user', 'birthday', 'gender'], dtype='object')

# %%
joined = joined.join(animes[['genre','episodes','score','popularity','ranked','uid']].set_index('uid'),on='anime_uid')
joined=joined.drop_duplicates()
joined.reset_index(inplace=True)
joined
# Out:
#          index     uid          profile  anime_uid  score_user      birthday  \
# 0            0  255938   DesolatePsyche      34096           8   Oct 2, 1994
# 1            1  259117        baekbeans      34599          10  Nov 10, 2000
# 2            2  253664             skrn      28891           7           NaN
# 3            3    8254     edgewalker00       2904           9         Sep 5
# 4            4  291149  aManOfCulture99       4181          10  Oct 30, 1999
# ...        ...     ...              ...        ...         ...           ...
# 131206  182629  146535        iHitokage       2593          10           NaN
# 131207  182631   13126           Onegai       2593           7           NaN
# 131208  182633  127899         Murasa22       2593          10  Feb 16, 1993
# 131209  182636  286852  srry4apologizng       2593           9           NaN
# 131210  182637  193145        bellellis       2593          10           NaN
#
#         gender  \
# 0         Male
# 1       Female
# 2          NaN
# 3         Male
# 4         Male
# ...        ...
# 131206    Male
# 131207    Male
# 131208    Male
# 131209     NaN
# 131210     NaN
#
#                                                                                genre  \
# 0       ['Action', 'Comedy', 'Historical', 'Parody', 'Samurai', 'Sci-Fi', 'Shounen']
# 1                             ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'Fantasy']
# 2                                 ['Comedy', 'Sports', 'Drama', 'School', 'Shounen']
# 3                  ['Action', 'Military', 'Sci-Fi', 'Super Power', 'Drama', 'Mecha']
# 4                    ['Slice of Life', 'Comedy', 'Supernatural', 'Drama', 'Romance']
# ...                                                                              ...
# 131206                             ['Action', 'Mystery', 'Supernatural', 'Thriller']
# 131207                             ['Action', 'Mystery', 'Supernatural', 'Thriller']
# 131208                             ['Action', 'Mystery', 'Supernatural', 'Thriller']
# 131209                             ['Action', 'Mystery', 'Supernatural', 'Thriller']
# 131210                             ['Action', 'Mystery', 'Supernatural', 'Thriller']
#
#         episodes  score  popularity  ranked
# 0           12.0   8.94         800    15.0
# 1           13.0   8.83          98    23.0
# 2           25.0   8.82         141    25.0
# 3           25.0   8.93          27    17.0
# 4           24.0   8.97          64    12.0
# ...          ...    ...         ...     ...
# 131206       1.0   7.70         358  1160.0
# 131207       1.0   7.70         358  1160.0
# 131208       1.0   7.70         358  1160.0
# 131209       1.0   7.70         358  1160.0
# 131210       1.0   7.70         358  1160.0
#
# [131211 rows x 12 columns]

# %% [markdown]
# # Corrida sin separar el genero

# %%
dls = fc.CollabDataLoaders.from_df(joined, user_name = 'uid', item_name = 'anime_uid', rating_name = 'score_user',bs=128)

# %%
# fc.CollabDataLoaders??

# %%
def flat_l1(yp, y): 
    return F.l1_loss(yp.view(-1), y.view(-1))

# %%
learn = fc.collab_learner(dls, opt_func = fc.ranger, use_nn=True, emb_szs={'uid':4,'anime_uid':4}, metrics=flat_l1)

# %%
print(learn.model)
learn.summary()
# Out:
# EmbeddingNN(
#   (embeds): ModuleList(
#     (0): Embedding(104522, 4)
#     (1): Embedding(7598, 4)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(0, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=8, out_features=50, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (1): LinBnDrop(
#       (0): Linear(in_features=50, out_features=1, bias=True)
#     )
#   )
# )
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# EmbeddingNN (Input shape: ['128 x 2'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Embedding            128 x 4              418,088    True
# ________________________________________________________________
# Embedding            128 x 4              30,392     True
# ________________________________________________________________
# Dropout              128 x 8              0          False
# ________________________________________________________________
# BatchNorm1d          128 x 8              16         True
# ________________________________________________________________
# Linear               128 x 50             400        True
# ________________________________________________________________
# ReLU                 128 x 50             0          False
# ________________________________________________________________
# Linear               128 x 1              51         True
# ________________________________________________________________
#
# Total params: 448,947
# Total trainable params: 448,947
# Total non-trainable params: 0
#
# Optimizer used: <function ranger at 0x7f7bb1e60dc0>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.33113112449646, lr_steep=0.10000000149011612)

# %%
learn.fit_one_cycle(20, 3e-2, div=1, pct_start=0.7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.533925</td>
#       <td>4.424016</td>
#       <td>1.675937</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.091526</td>
#       <td>4.519840</td>
#       <td>1.745517</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.354317</td>
#       <td>4.282805</td>
#       <td>1.639064</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.935279</td>
#       <td>4.279785</td>
#       <td>1.614612</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.697978</td>
#       <td>4.302416</td>
#       <td>1.665082</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.693505</td>
#       <td>4.311435</td>
#       <td>1.672701</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.585554</td>
#       <td>4.376511</td>
#       <td>1.697857</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.575785</td>
#       <td>4.373689</td>
#       <td>1.698953</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.585792</td>
#       <td>4.288881</td>
#       <td>1.647571</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.493130</td>
#       <td>4.314792</td>
#       <td>1.664885</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.576902</td>
#       <td>4.370528</td>
#       <td>1.689389</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.464409</td>
#       <td>4.303413</td>
#       <td>1.662337</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.514051</td>
#       <td>4.433235</td>
#       <td>1.705847</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.461249</td>
#       <td>4.279826</td>
#       <td>1.639605</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.525757</td>
#       <td>4.428031</td>
#       <td>1.700588</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.448828</td>
#       <td>4.466453</td>
#       <td>1.712924</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.343334</td>
#       <td>4.518976</td>
#       <td>1.718028</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.210883</td>
#       <td>4.404809</td>
#       <td>1.681225</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.100789</td>
#       <td>4.535780</td>
#       <td>1.721832</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.066769</td>
#       <td>4.396231</td>
#       <td>1.681234</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = fc.collab_learner(dls, opt_func = fc.ranger, use_nn = True, emb_szs = {'uid': 8, 'anime_uid': 8}, layers = [1024, 512], metrics=flat_l1)

# %%
print(learn.model)
learn.summary()
# Out:
# EmbeddingNN(
#   (embeds): ModuleList(
#     (0): Embedding(104522, 8)
#     (1): Embedding(7578, 8)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(0, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=16, out_features=1024, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (1): LinBnDrop(
#       (0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=1024, out_features=512, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (2): LinBnDrop(
#       (0): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
# )
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# EmbeddingNN (Input shape: ['128 x 2'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Embedding            128 x 8              836,176    True
# ________________________________________________________________
# Embedding            128 x 8              60,624     True
# ________________________________________________________________
# Dropout              128 x 16             0          False
# ________________________________________________________________
# BatchNorm1d          128 x 16             32         True
# ________________________________________________________________
# Linear               128 x 1024           16,384     True
# ________________________________________________________________
# ReLU                 128 x 512            0          False
# ________________________________________________________________
# BatchNorm1d          128 x 1024           2,048      True
# ________________________________________________________________
# Linear               128 x 512            524,288    True
# ________________________________________________________________
# ReLU                 128 x 512            0          False
# ________________________________________________________________
# Linear               128 x 1              513        True
# ________________________________________________________________
#
# Total params: 1,440,065
# Total trainable params: 1,440,065
# Total non-trainable params: 0
#
# Optimizer used: <function ranger at 0x7f7bb1e60dc0>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.03019951581954956, lr_steep=0.004365158267319202)

# %%
learn.fit_one_cycle(20, 3e-2, div=1, pct_start=0.7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.646179</td>
#       <td>4.385288</td>
#       <td>1.674258</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.989937</td>
#       <td>4.237473</td>
#       <td>1.590337</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.599582</td>
#       <td>4.301905</td>
#       <td>1.659747</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.080799</td>
#       <td>4.257716</td>
#       <td>1.594041</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.774292</td>
#       <td>4.370381</td>
#       <td>1.624807</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.759662</td>
#       <td>4.263653</td>
#       <td>1.573441</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.706245</td>
#       <td>4.262120</td>
#       <td>1.621441</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.612663</td>
#       <td>4.201376</td>
#       <td>1.593012</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.587107</td>
#       <td>4.437133</td>
#       <td>1.602406</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.535675</td>
#       <td>4.220559</td>
#       <td>1.621084</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.484960</td>
#       <td>4.444666</td>
#       <td>1.597015</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.523378</td>
#       <td>4.739438</td>
#       <td>1.654939</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.458313</td>
#       <td>5.423398</td>
#       <td>1.637464</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.488010</td>
#       <td>4.296462</td>
#       <td>1.638140</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.495337</td>
#       <td>4.253127</td>
#       <td>1.623806</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.448389</td>
#       <td>4.280648</td>
#       <td>1.624668</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.333415</td>
#       <td>4.315960</td>
#       <td>1.648184</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.204627</td>
#       <td>4.267214</td>
#       <td>1.608708</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.108782</td>
#       <td>4.246727</td>
#       <td>1.604352</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.075128</td>
#       <td>4.251287</td>
#       <td>1.607083</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Corrida separando los generos

# %%
generos=joined['genre'].unique()
generos
# Out:
# array(["['Action', 'Comedy', 'Historical', 'Parody', 'Samurai', 'Sci-Fi', 'Shounen']",
#        "['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'Fantasy']",
#        "['Comedy', 'Sports', 'Drama', 'School', 'Shounen']", ...,
#        "['Action', 'Drama', 'Mecha', 'Music', 'Mystery', 'Psychological', 'Romance', 'Sci-Fi']",
#        "['Action', 'Military', 'Adventure', 'Mecha']",
#        "['Drama', 'Mecha', 'Psychological', 'Sci-Fi']"], dtype=object)

# %%
gener_list=[]

for elemento in generos:
    tmp=[g.replace('[','').replace(']','').replace("'","").replace(' ','') for g in elemento.split(',')]
    for g in tmp:
        gener_list.append(g)
        
        
gener_list=list(set(gener_list))

while '' in gener_list:
    gener_list.remove('')
    
gener_list
# Out:
# ['Historical',
#  'Demons',
#  'ShoujoAi',
#  'Horror',
#  'Thriller',
#  'MartialArts',
#  'Magic',
#  'School',
#  'Adventure',
#  'Sci-Fi',
#  'Shoujo',
#  'Parody',
#  'Josei',
#  'Drama',
#  'Romance',
#  'Fantasy',
#  'Comedy',
#  'Shounen',
#  'Psychological',
#  'Cars',
#  'Dementia',
#  'Action',
#  'Mystery',
#  'Harem',
#  'Supernatural',
#  'Military',
#  'Game',
#  'Kids',
#  'Hentai',
#  'SuperPower',
#  'ShounenAi',
#  'Mecha',
#  'SliceofLife',
#  'Yuri',
#  'Seinen',
#  'Yaoi',
#  'Police',
#  'Space',
#  'Vampire',
#  'Music',
#  'Samurai',
#  'Ecchi',
#  'Sports']

# %%
joined.columns
# Out:
# Index(['index', 'uid', 'profile', 'anime_uid', 'score_user', 'birthday',
#        'gender', 'genre', 'episodes', 'score', 'popularity', 'ranked'],
#       dtype='object')

# %%
copia_p=pd.DataFrame(index=range(len(joined['genre'])))

# %%
for elemento in gener_list:
    copia_p[elemento]=False

# %%
copia_p['genre'] = joined['genre']

# %%
for cont,elemento in enumerate(generos):
    if cont%100 ==0:
        print(cont)
        
    tmp=[g.replace('[','').replace(']','').replace("'","").replace(' ','') for g in elemento.split(',')]
    aux=copia_p['genre']==elemento
    for i in copia_p[aux].index:
        for x in tmp:
            copia_p.loc[i,[x]]=True
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600

# %%
copia_p.drop('',axis=1,inplace=True)

# %%
copia_p['uid']=joined['uid']

# %%
joined=joined.join(copia_p.drop(['genre'],axis=1).set_index('uid'),on='uid')

# %%
joined.drop(['genre'],axis=1,inplace=True)

# %%
joined
# Out:
#          index     uid          profile  anime_uid  score_user      birthday  \
# 0            0  255938   DesolatePsyche      34096           8   Oct 2, 1994
# 1            1  259117        baekbeans      34599          10  Nov 10, 2000
# 2            2  253664             skrn      28891           7           NaN
# 3            3    8254     edgewalker00       2904           9         Sep 5
# 4            4  291149  aManOfCulture99       4181          10  Oct 30, 1999
# ...        ...     ...              ...        ...         ...           ...
# 131206  182629  146535        iHitokage       2593          10           NaN
# 131207  182631   13126           Onegai       2593           7           NaN
# 131208  182633  127899         Murasa22       2593          10  Feb 16, 1993
# 131209  182636  286852  srry4apologizng       2593           9           NaN
# 131210  182637  193145        bellellis       2593          10           NaN
#
#         gender  episodes  score  popularity  ...   Yuri  Seinen   Yaoi  \
# 0         Male      12.0   8.94         800  ...  False   False  False
# 1       Female      13.0   8.83          98  ...  False   False  False
# 2          NaN      25.0   8.82         141  ...  False   False  False
# 3         Male      25.0   8.93          27  ...  False   False  False
# 4         Male      24.0   8.97          64  ...  False   False  False
# ...        ...       ...    ...         ...  ...    ...     ...    ...
# 131206    Male       1.0   7.70         358  ...  False   False  False
# 131207    Male       1.0   7.70         358  ...  False   False  False
# 131208    Male       1.0   7.70         358  ...  False   False  False
# 131209     NaN       1.0   7.70         358  ...  False   False  False
# 131210     NaN       1.0   7.70         358  ...  False   False  False
#
#         Police  Space  Vampire  Music  Samurai  Ecchi  Sports
# 0        False  False    False  False     True  False   False
# 1        False  False    False  False    False  False   False
# 2        False  False    False  False    False  False    True
# 3        False  False    False  False    False  False   False
# 4        False  False    False  False    False  False   False
# ...        ...    ...      ...    ...      ...    ...     ...
# 131206   False  False    False  False    False  False   False
# 131207   False  False    False  False    False  False   False
# 131208   False  False    False  False    False  False   False
# 131209   False  False    False  False    False  False   False
# 131210   False  False    False  False    False  False   False
#
# [132595 rows x 54 columns]

# %%
dls = fc.CollabDataLoaders.from_df(joined, user_name = 'uid', item_name = 'anime_uid', rating_name = 'score_user',bs=128)

# %%
learn = fc.collab_learner(dls, opt_func = fc.ranger, use_nn = True, emb_szs = {'uid': 8, 'anime_uid': 8}, layers = [1024, 512], metrics=flat_l1)

# %%
print(learn.model)
learn.summary()
# Out:
# EmbeddingNN(
#   (embeds): ModuleList(
#     (0): Embedding(104522, 8)
#     (1): Embedding(7578, 8)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(0, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=16, out_features=1024, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (1): LinBnDrop(
#       (0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=1024, out_features=512, bias=False)
#       (2): ReLU(inplace=True)
#     )
#     (2): LinBnDrop(
#       (0): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
# )
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# EmbeddingNN (Input shape: ['128 x 2'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Embedding            128 x 8              836,176    True
# ________________________________________________________________
# Embedding            128 x 8              60,624     True
# ________________________________________________________________
# Dropout              128 x 16             0          False
# ________________________________________________________________
# BatchNorm1d          128 x 16             32         True
# ________________________________________________________________
# Linear               128 x 1024           16,384     True
# ________________________________________________________________
# ReLU                 128 x 512            0          False
# ________________________________________________________________
# BatchNorm1d          128 x 1024           2,048      True
# ________________________________________________________________
# Linear               128 x 512            524,288    True
# ________________________________________________________________
# ReLU                 128 x 512            0          False
# ________________________________________________________________
# Linear               128 x 1              513        True
# ________________________________________________________________
#
# Total params: 1,440,065
# Total trainable params: 1,440,065
# Total non-trainable params: 0
#
# Optimizer used: <function ranger at 0x7f7bb1e60dc0>
# Loss function: FlattenedLoss of MSELoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.025118863582611083, lr_steep=0.004365158267319202)

# %%
learn.fit_one_cycle(20, 3e-2, div=1, pct_start=0.7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>flat_l1</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.598846</td>
#       <td>4.420057</td>
#       <td>1.679916</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.098883</td>
#       <td>4.243650</td>
#       <td>1.596543</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.808276</td>
#       <td>4.327211</td>
#       <td>1.660436</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.205061</td>
#       <td>4.230621</td>
#       <td>1.615626</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.838473</td>
#       <td>4.223528</td>
#       <td>1.602379</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.792701</td>
#       <td>4.510499</td>
#       <td>1.612976</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.669621</td>
#       <td>4.208754</td>
#       <td>1.611400</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.645375</td>
#       <td>4.341780</td>
#       <td>1.679267</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.601055</td>
#       <td>5.038640</td>
#       <td>1.633628</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.583432</td>
#       <td>4.277260</td>
#       <td>1.616838</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.552507</td>
#       <td>4.232004</td>
#       <td>1.618374</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.529263</td>
#       <td>4.247843</td>
#       <td>1.623128</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.499701</td>
#       <td>4.645029</td>
#       <td>1.605104</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.500650</td>
#       <td>4.280845</td>
#       <td>1.593376</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.550158</td>
#       <td>4.286996</td>
#       <td>1.593500</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.497039</td>
#       <td>4.278607</td>
#       <td>1.618175</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.364825</td>
#       <td>4.277264</td>
#       <td>1.581341</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.215786</td>
#       <td>4.260607</td>
#       <td>1.584580</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.123910</td>
#       <td>4.289812</td>
#       <td>1.582149</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.082989</td>
#       <td>4.264192</td>
#       <td>1.588087</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
